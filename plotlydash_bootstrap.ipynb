# %%
#pip install dash-bootstrap-components
# Out:
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-0.11.1-py2.py3-none-any.whl (187 kB)
# Requirement already satisfied: dash>=1.9.0 in c:\users\rakes\anaconda3\lib\site-packages (from dash-bootstrap-components) (1.18.1)
# Requirement already satisfied: dash-html-components==1.1.1 in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.1.1)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.1.1)
# Requirement already satisfied: future in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (0.18.2)
# Requirement already satisfied: plotly in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (4.14.1)
# Requirement already satisfied: dash-renderer==1.8.3 in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.8.3)
# Requirement already satisfied: flask-compress in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.8.0)
# Requirement already satisfied: dash-core-components==1.14.1 in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (1.14.1)
# Requirement already satisfied: dash-table==4.11.1 in c:\users\rakes\anaconda3\lib\site-packages (from dash>=1.9.0->dash-bootstrap-components) (4.11.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\rakes\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (2.11.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\rakes\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\rakes\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (1.0.0)
# Requirement already satisfied: click>=5.1 in c:\users\rakes\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (7.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\rakes\anaconda3\lib\site-packages (from plotly->dash>=1.9.0->dash-bootstrap-components) (1.3.3)
# Requirement already satisfied: six in c:\users\rakes\anaconda3\lib\site-packages (from plotly->dash>=1.9.0->dash-bootstrap-components) (1.14.0)
# Requirement already satisfied: brotli in c:\users\rakes\anaconda3\lib\site-packages (from flask-compress->dash>=1.9.0->dash-bootstrap-components) (1.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rakes\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=1.9.0->dash-bootstrap-components) (1.1.1)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-0.11.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the 'C:\Users\rakes\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import dash
import dash_bootstrap_components as dbc
import dash_html_components as html

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = html.Div([
    dbc.Button("Success",color = "success",className ="mr-1")
    
])


if __name__ == "__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Jan/2021 19:05:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jan/2021 19:05:36] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jan/2021 19:05:36] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
import dash_bootstrap_components as dbc
import dash_html_components as html

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

alert = dbc.Alert([
html.H4('Weldone!! ', className = 'alert-heading'),
    
    html.P(
            "This is a success alert with loads of extra text in it. So much "
            "that you can see how spacing within an alert works with this "
            "kind of content."
        ),
    html.Hr(),
        html.P(
            "Let's put some more text down here, but remove the bottom margin",
            className="mb-0",
        ),
]
)



if __name__ == "__main__":
    app.run_server(port = 4020)
# Out:
# Dash is running on http://127.0.0.1:4020/
#
# Dash is running on http://127.0.0.1:4020/
#
# Dash is running on http://127.0.0.1:4020/
#
# Dash is running on http://127.0.0.1:4020/
#
# Dash is running on http://127.0.0.1:4020/
#
# Dash is running on http://127.0.0.1:4020/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4020/ (Press CTRL+C to quit)
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# 127.0.0.1 - - [12/Jan/2021 20:24:58] "GET / HTTP/1.1" 500 -
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\dash.py", line 1093, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "C:\Users\rakes\anaconda3\lib\site-packages\dash\_validate.py", line 339, in validate_layout
#     """
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
# 127.0.0.1 - - [12/Jan/2021 20:24:58] "GET /favicon.ico HTTP/1.1" 500 -

# %%
import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

df = pd.read_csv("Berlin_crimes.csv")
#df.head()
df = df.groupby('District')[['Street_robbery', 'Drugs']].median()
#df.head()


app.layout = html.Div([
    
    dbc.Row(dbc.Col(html.H3("Beautiful Layout"), width = {'size':6 , 'offset': 3},),),
    
    dbc.Row(dbc.Col(html.Div("one column is all blabla !!!!!!"), width = 4)),
    
    dbc.Row(
            [
                dbc.Col(dcc.Dropdown(id='c_dropdown', placeholder='last dropdown',
                                     options=[{'label': 'Option A', 'value': 'optA'},
                                              {'label': 'Option B', 'value': 'optB'}]),
                        width={'size': 3, "offset": 2, 'order': 3}
                        ),
                dbc.Col(dcc.Dropdown(id='a_dropdown', placeholder='first dropdown',
                                     options=[{'label': 'Option A', 'value': 'optA'},
                                              {'label': 'Option B', 'value': 'optB'}]),
                        width={'size': 4, "offset": 1, 'order': 1}
                        ),
                dbc.Col(dcc.Dropdown(id='b_dropdown', placeholder='middle dropdown',
                                     options=[{'label': 'Option A', 'value': 'optA'},
                                              {'label': 'Option B', 'value': 'optB'}]),
                        width={'size': 2,  "offset": 0, 'order': 2}
                        ),
            ], no_gutters=True
        ),
    
    
     dbc.Row(
            [
                dbc.Col(dcc.Graph(id='pie_chart1', figure={}),
                        width=8, lg={'size': 6,  "offset": 0, 'order': 'first'}
                        ),
                dbc.Col(dcc.Graph(id='pie_chart2', figure={}),
                        width=4, lg={'size': 6,  "offset": 0, 'order': 'last'}
                        ),
            ]
        )
    
  

])


@app.callback(
 [Output('pie_chart1', 'figure'),
     Output('pie_chart2', 'figure')],
    [Input('a_dropdown', 'value'),
     Input('b_dropdown', 'value'),
     Input('c_dropdown', 'value')]


)



def update_graph(dpdn_a, dpdn_b, dpdn_c):
    dff = df[:200]
    if dpdn_a is None or dpdn_b is None or dpdn_c is None:
        pie_fig = px.pie(dff, names=dff.index, values='Street_robbery', title='Street Robbery Berlin')\
            .update_layout(showlegend=False, title_x=0.7).update_traces(textposition='inside',  textinfo='label+percent')
        pie_fig2 = px.pie(dff, names=dff.index, values='Drugs', title='Drugs Berlin')\
            .update_layout(showlegend=False, title_x=0.7).update_traces(textposition='inside', textinfo='label+percent')
        return pie_fig, pie_fig2
    else:
        raise dash.exceptions.PreventUpdate


if __name__ == "__main__":
    app.run_server(port=4020)
# Out:
# Dash is running on http://127.0.0.1:4020/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4020/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_8_3m1610116146.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_renderer/react@16.v1_8_3m1610116146.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_8_3m1610116146.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_14_1m1610116146.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_8_3m1610116146.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_14_1m1610116146.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_11_1m1610469645.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_1m1610116147.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_8_3m1610116146.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_core_components/async-graph.v1_14_1m1607534654.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:48] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_14_1m1607534654.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:49] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_14_1m1607534654.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jan/2021 16:32:49] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
df1.District
